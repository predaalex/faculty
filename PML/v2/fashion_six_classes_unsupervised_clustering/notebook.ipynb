# %%
import warnings

import kagglehub
from tqdm import tqdm

# Download latest version
path = kagglehub.dataset_download("ziadhanyai/fashion-six-classes")
print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.6)
# Path to dataset files: C:\Users\allex\.cache\kagglehub\datasets\ziadhanyai\fashion-six-classes\versions\1

# %%
import os

dataset_path = os.path.join(path, "Fashion")
class_to_int = {}
for idx, class_name in enumerate(os.listdir(dataset_path)):
    class_to_int[class_name] = idx
class_to_int
# Out:
# {'Accessories': 0,
#  'Formal': 1,
#  'Hoodie': 2,
#  'Pants': 3,
#  'Shoes': 4,
#  'T-Shirt': 5}

# %%
import pandas as pd
import cv2 as cv
warnings.filterwarnings("ignore", category=UserWarning)  # Disable UserWarnings
tqdm.pandas()

df = pd.DataFrame(columns=["ImageName", "OriginalImage", "Label"])

for class_name, class_idx in class_to_int.items():
    # put images with labels into dataframe
    img_dir_class = os.path.join(dataset_path, class_name)
    for img_path in tqdm(os.listdir(img_dir_class)):
        full_img_path = os.path.join(img_dir_class, img_path)
        if img_path.endswith(".jpg") or img_path.endswith(".png") or img_path.endswith(".jpeg"):
            img = cv.imread(full_img_path)
            img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
            img = cv.resize(img, (224, 224), interpolation=cv.INTER_CUBIC)
            df.loc[len(df)] = [img_path, img, class_name]
# Out:
# 100%|██████████| 1140/1140 [00:20<00:00, 54.62it/s]
# 100%|██████████| 1064/1064 [00:14<00:00, 71.82it/s]
# 100%|██████████| 1089/1089 [00:16<00:00, 68.00it/s]
# 100%|██████████| 1001/1001 [00:16<00:00, 60.73it/s]
# 100%|██████████| 1050/1050 [00:17<00:00, 59.09it/s]
# 100%|██████████| 1063/1063 [00:16<00:00, 64.23it/s]

# %%
df.iloc[0]
# Out:
# ImageName                                              Image_1.png
# OriginalImage    [[[255, 255, 255], [255, 255, 255], [255, 255,...
# Label                                                  Accessories
# Name: 0, dtype: object

# %% [markdown]
# # Image Representation A (Simple flattening of Gray Scaled Images)

# %%
df["FlattenedImage"] = df["OriginalImage"].progress_apply(lambda x: cv.cvtColor(x, cv.COLOR_RGB2GRAY).flatten() / 255.0)
# Out:
# 100%|██████████| 6343/6343 [00:00<00:00, 6693.80it/s]

# %% [markdown]
# # Image Representation B (ResNet embeddings)

# %%
import torch
from torchvision import models, transforms

# Load pretrained ResNet model
resnet = models.resnet18(pretrained=True)
resnet.eval()  # Set to evaluation mode
resnet = torch.nn.Sequential(*list(resnet.children())[:-1])
# Define image transformation
transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Function to extract features from image
def get_resnet_features(image_array):
    image_tensor = transform(image_array).unsqueeze(0)  # Add batch dimension
    with torch.no_grad():  # No need to track gradients
        features = resnet(image_tensor)  # Get features from the ResNet model
    return features.squeeze().numpy()  # Remove batch dimension and convert to numpy array

# Apply ResNet feature extraction on the "Image" column
df["ResNetFeatures"] = df["OriginalImage"].progress_apply(lambda x: get_resnet_features(x))
# Out:
# 100%|██████████| 6343/6343 [01:16<00:00, 82.58it/s]

# %%
import numpy as np
from sklearn.model_selection import train_test_split

X_train_flatten, X_val_flatten, y_train_flatten, y_val_flatten = train_test_split(np.array(df['FlattenedImage'].tolist()), df['Label'], test_size=0.2, random_state=42)
X_train_resnet, X_val_resnet, y_train_resnet, y_val_resnet = train_test_split(np.array(df['ResNetFeatures'].tolist()), df['Label'], test_size=0.2, random_state=42)

# %%
X_train_flatten.shape
# Out:
# (5074, 50176)

# %%
from sklearn.decomposition import PCA

# Initialize PCA with the number of components you want to keep.
# For example, to reduce to 50 components:
pca = PCA(n_components=50)

# Fit the PCA on the training data and transform it
X_train_flatten_pca = pca.fit_transform(X_train_flatten)

# Optionally, you can also transform the validation set with the same PCA model
X_val_flatten_pca = pca.transform(X_val_flatten)

# Check the new shape
print("New training data shape:", X_train_flatten_pca.shape)
print("New validation data shape:", X_val_flatten_pca.shape)
# Out:
# New training data shape: (5074, 50)
# New validation data shape: (1269, 50)

# %% [markdown]
# # DBSCAN

# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics import adjusted_rand_score, silhouette_score, davies_bouldin_score, calinski_harabasz_score

# Function to evaluate DBSCAN performance for a given combination of hyperparameters
def evaluate_dbscan(model, X, y):
    y_pred = model.labels_
    
    # Ignore noise points (label -1)
    mask = y_pred != -1
    X_filtered = X[mask]
    y_filtered = y[mask]
    y_pred_filtered = y_pred[mask]
    
    nr_of_removed_labels = len(y) - len(y_filtered)
    print(f"Removed {nr_of_removed_labels} out of {len(y)} as noise (-1 label)")
    if nr_of_removed_labels > len(y) / 2: # half of labels
        print(f"HALF OF DATA IS REMOVED!")
        return -1, -1, -1, -1
    
    silhouette_avg = -1
    davies_bouldin = -1
    calinski_harabasz = -1
    ari = -1
    
    if len(np.unique(y_pred_filtered)) > 1:
        # Silhouette Coefficient (higher is better)
        silhouette_avg = silhouette_score(X_filtered, y_pred_filtered)
        print(f"Silhouette Coefficient: {silhouette_avg:.4f}")
        
        # Davies-Bouldin Index (lower is better)
        davies_bouldin = davies_bouldin_score(X_filtered, y_pred_filtered)
        print(f"Davies-Bouldin Index: {davies_bouldin:.4f}")
        
        # Calinski-Harabasz Index (higher is better)
        calinski_harabasz = calinski_harabasz_score(X_filtered, y_pred_filtered)
        print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f}")
        
        # Optionally, print ARI for comparison with true labels
        ari = adjusted_rand_score(y_filtered, y_pred_filtered)
        print(f"Adjusted Rand Index (ARI): {ari:.4f}")
        
        print(f"Number of clusters detected: {len(np.unique(y_pred_filtered))}")
    else:
        print("Metrics cannot be computed (only 1 cluster found)")
    
    return silhouette_avg, davies_bouldin, calinski_harabasz, ari

# %% [markdown]
# # DBSCAN + Representation A

# %%
from sklearn.model_selection import ParameterGrid

# Define the hyperparameter grid for tuning
param_grid = {
    'eps': [30, 35, 40, 45, 50, 60, 70 ,80 ,90, 100, 125, 150, 175],  # Range for eps
    'min_samples': [3, 5, 7, 10, 15]  # Range for min_samples
}

# Convert the grid into parameter combinations
grid = ParameterGrid(param_grid)

# Iterate over each parameter combination and evaluate
best_silhouette_avg = -1  # Track the best ARI score
best_params = None  # Track the best hyperparameters
results_dbscan_respresentation_A = {
    "min_samples": [],
    "eps": [],
    "silhouette_avg": [],
    "davies_bouldin": [],
    "calinski_harabasz": [],
    "ari": [],
}

for params in grid:
    eps = params['eps']
    min_samples = params['min_samples']
    
    print(f"Evaluating: eps={eps}, min_samples={min_samples}")

    dbscan = DBSCAN(eps=eps, min_samples=min_samples)
    dbscan.fit_predict(X_train_flatten)
    silhouette_avg, davies_bouldin, calinski_harabasz, ari = evaluate_dbscan(dbscan, X_train_flatten, y_train_flatten)
    
    results_dbscan_respresentation_A['min_samples'].append(min_samples)
    results_dbscan_respresentation_A['eps'].append(eps)
    results_dbscan_respresentation_A['silhouette_avg'].append(silhouette_avg)
    results_dbscan_respresentation_A['davies_bouldin'].append(davies_bouldin)
    results_dbscan_respresentation_A['calinski_harabasz'].append(calinski_harabasz)
    results_dbscan_respresentation_A['ari'].append(ari)
    print()
    
    if silhouette_avg > best_silhouette_avg:
        best_silhouette_avg = silhouette_avg
        best_params = params

print(f"\nBest Silhouette: {best_silhouette_avg} with parameters: {best_params}")
# Out:
# Evaluating: eps=30, min_samples=3
# Removed 4333 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=30, min_samples=5
# Removed 4646 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=30, min_samples=7
# Removed 4721 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=30, min_samples=10
# Removed 4731 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=30, min_samples=15
# Removed 4742 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=35, min_samples=3
# Removed 4059 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=35, min_samples=5
# Removed 4364 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=35, min_samples=7
# Removed 4442 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=35, min_samples=10
# Removed 4478 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=35, min_samples=15
# Removed 4514 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=40, min_samples=3
# Removed 3641 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=40, min_samples=5
# Removed 3917 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=40, min_samples=7
# Removed 4004 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=40, min_samples=10
# Removed 4070 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=40, min_samples=15
# Removed 4105 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=45, min_samples=3
# Removed 3108 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=45, min_samples=5
# Removed 3383 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=45, min_samples=7
# Removed 3472 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=45, min_samples=10
# Removed 3546 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=45, min_samples=15
# Removed 3609 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=50, min_samples=3
# Removed 2329 out of 5074 as noise (-1 label)
# Silhouette Coefficient: -0.1787
# Davies-Bouldin Index: 0.9883
# Calinski-Harabasz Index: 5.4420
# Adjusted Rand Index (ARI): 0.0021
# Number of clusters detected: 63
#
# Evaluating: eps=50, min_samples=5
# Removed 2528 out of 5074 as noise (-1 label)
# Silhouette Coefficient: 0.0166
# Davies-Bouldin Index: 0.9817
# Calinski-Harabasz Index: 10.3984
# Adjusted Rand Index (ARI): -0.0003
# Number of clusters detected: 10
#
# Evaluating: eps=50, min_samples=7
# Removed 2610 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=50, min_samples=10
# Removed 2726 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=50, min_samples=15
# Removed 2796 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=60, min_samples=3
# Removed 957 out of 5074 as noise (-1 label)
# Silhouette Coefficient: -0.1222
# Davies-Bouldin Index: 1.0686
# Calinski-Harabasz Index: 4.8582
# Adjusted Rand Index (ARI): 0.0005
# Number of clusters detected: 30
#
# Evaluating: eps=60, min_samples=5
# Removed 1063 out of 5074 as noise (-1 label)
# Silhouette Coefficient: 0.0706
# Davies-Bouldin Index: 1.1725
# Calinski-Harabasz Index: 10.6424
# Adjusted Rand Index (ARI): 0.0001
# Number of clusters detected: 4
#
# Evaluating: eps=60, min_samples=7
# Removed 1099 out of 5074 as noise (-1 label)
# Silhouette Coefficient: 0.1687
# Davies-Bouldin Index: 1.0046
# Calinski-Harabasz Index: 16.8773
# Adjusted Rand Index (ARI): -0.0000
# Number of clusters detected: 2
#
# Evaluating: eps=60, min_samples=10
# Removed 1122 out of 5074 as noise (-1 label)
# Silhouette Coefficient: 0.1706
# Davies-Bouldin Index: 1.0017
# Calinski-Harabasz Index: 16.9919
# Adjusted Rand Index (ARI): 0.0000
# Number of clusters detected: 2
#
# Evaluating: eps=60, min_samples=15
# Removed 1161 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=70, min_samples=3
# Removed 250 out of 5074 as noise (-1 label)
# Silhouette Coefficient: 0.0165
# Davies-Bouldin Index: 1.1374
# Calinski-Harabasz Index: 5.0946
# Adjusted Rand Index (ARI): 0.0001
# Number of clusters detected: 6
#
# Evaluating: eps=70, min_samples=5
# Removed 267 out of 5074 as noise (-1 label)
# Silhouette Coefficient: 0.0538
# Davies-Bouldin Index: 1.2742
# Calinski-Harabasz Index: 6.9148
# Adjusted Rand Index (ARI): 0.0000
# Number of clusters detected: 3
#
# Evaluating: eps=70, min_samples=7
# Removed 283 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=70, min_samples=10
# Removed 289 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=70, min_samples=15
# Removed 305 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=80, min_samples=3
# Removed 49 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=80, min_samples=5
# Removed 49 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=80, min_samples=7
# Removed 49 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=80, min_samples=10
# Removed 49 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=80, min_samples=15
# Removed 50 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=90, min_samples=3
# Removed 7 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=90, min_samples=5
# Removed 7 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=90, min_samples=7
# Removed 7 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=90, min_samples=10
# Removed 7 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=90, min_samples=15
# Removed 7 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=100, min_samples=3
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=100, min_samples=5
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=100, min_samples=7
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=100, min_samples=10
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=100, min_samples=15
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=125, min_samples=3
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=125, min_samples=5
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=125, min_samples=7
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=125, min_samples=10
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=125, min_samples=15
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=150, min_samples=3
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=150, min_samples=5
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=150, min_samples=7
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=150, min_samples=10
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=150, min_samples=15
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=175, min_samples=3
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=175, min_samples=5
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=175, min_samples=7
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=175, min_samples=10
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=175, min_samples=15
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
#
# Best Silhouette: 0.17055004535671284 with parameters: {'eps': 60, 'min_samples': 10}

# %%
df_results_A = pd.DataFrame(results_dbscan_respresentation_A)
df_results_A
# Out:
#     min_samples  eps  silhouette_avg  davies_bouldin  calinski_harabasz  ari
# 0             3   30            -1.0            -1.0               -1.0 -1.0
# 1             5   30            -1.0            -1.0               -1.0 -1.0
# 2             7   30            -1.0            -1.0               -1.0 -1.0
# 3            10   30            -1.0            -1.0               -1.0 -1.0
# 4            15   30            -1.0            -1.0               -1.0 -1.0
# ..          ...  ...             ...             ...                ...  ...
# 60            3  175            -1.0            -1.0               -1.0 -1.0
# 61            5  175            -1.0            -1.0               -1.0 -1.0
# 62            7  175            -1.0            -1.0               -1.0 -1.0
# 63           10  175            -1.0            -1.0               -1.0 -1.0
# 64           15  175            -1.0            -1.0               -1.0 -1.0
#
# [65 rows x 6 columns]

# %% [markdown]
# # DBSCAN + Representation B

# %%
from sklearn.model_selection import ParameterGrid

# Define the hyperparameter grid for tuning
param_grid = {
    'eps': [30, 35, 40, 45, 50, 60, 70 ,80 ,90, 100, 125, 150, 175],  # Range for eps
    'min_samples': [3, 5, 7, 10, 15]  # Range for min_samples
}

# Convert the grid into parameter combinations
grid = ParameterGrid(param_grid)

# Iterate over each parameter combination and evaluate
best_silhouette_avg = -1  # Track the best ARI score
best_params = None  # Track the best hyperparameters
results_dbscan_respresentation_B = {
    "min_samples": [],
    "eps": [],
    "silhouette_avg": [],
    "davies_bouldin": [],
    "calinski_harabasz": [],
    "ari": [],
    }

for params in grid:
    eps = params['eps']
    min_samples = params['min_samples']
    
    print(f"Evaluating: eps={eps}, min_samples={min_samples}")

    dbscan = DBSCAN(eps=eps, min_samples=min_samples)
    dbscan.fit_predict(X_train_flatten)
    silhouette_avg, davies_bouldin, calinski_harabasz, ari = evaluate_dbscan(dbscan, X_train_flatten, y_train_flatten)
    
    results_dbscan_respresentation_B['min_samples'].append(min_samples)
    results_dbscan_respresentation_B['eps'].append(eps)
    results_dbscan_respresentation_B['silhouette_avg'].append(silhouette_avg)
    results_dbscan_respresentation_B['davies_bouldin'].append(davies_bouldin)
    results_dbscan_respresentation_B['calinski_harabasz'].append(calinski_harabasz)
    results_dbscan_respresentation_B['ari'].append(ari)
    print()
    
    if silhouette_avg > best_silhouette_avg:
        best_silhouette_avg = silhouette_avg
        best_params = params

print(f"\nBest Silhouette: {best_silhouette_avg} with parameters: {best_params}")
# Out:
# Evaluating: eps=30, min_samples=3
# Removed 4333 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=30, min_samples=5
# Removed 4646 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=30, min_samples=7
# Removed 4721 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=30, min_samples=10
# Removed 4731 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=30, min_samples=15
# Removed 4742 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=35, min_samples=3
# Removed 4059 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=35, min_samples=5
# Removed 4364 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=35, min_samples=7
# Removed 4442 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=35, min_samples=10
# Removed 4478 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=35, min_samples=15
# Removed 4514 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=40, min_samples=3
# Removed 3641 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=40, min_samples=5
# Removed 3917 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=40, min_samples=7
# Removed 4004 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=40, min_samples=10
# Removed 4070 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=40, min_samples=15
# Removed 4105 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=45, min_samples=3
# Removed 3108 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=45, min_samples=5
# Removed 3383 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=45, min_samples=7
# Removed 3472 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=45, min_samples=10
# Removed 3546 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=45, min_samples=15
# Removed 3609 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=50, min_samples=3
# Removed 2329 out of 5074 as noise (-1 label)
# Silhouette Coefficient: -0.1787
# Davies-Bouldin Index: 0.9883
# Calinski-Harabasz Index: 5.4420
# Adjusted Rand Index (ARI): 0.0021
# Number of clusters detected: 63
#
# Evaluating: eps=50, min_samples=5
# Removed 2528 out of 5074 as noise (-1 label)
# Silhouette Coefficient: 0.0166
# Davies-Bouldin Index: 0.9817
# Calinski-Harabasz Index: 10.3984
# Adjusted Rand Index (ARI): -0.0003
# Number of clusters detected: 10
#
# Evaluating: eps=50, min_samples=7
# Removed 2610 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=50, min_samples=10
# Removed 2726 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=50, min_samples=15
# Removed 2796 out of 5074 as noise (-1 label)
# HALF OF DATA IS REMOVED!
#
# Evaluating: eps=60, min_samples=3
# Removed 957 out of 5074 as noise (-1 label)
# Silhouette Coefficient: -0.1222
# Davies-Bouldin Index: 1.0686
# Calinski-Harabasz Index: 4.8582
# Adjusted Rand Index (ARI): 0.0005
# Number of clusters detected: 30
#
# Evaluating: eps=60, min_samples=5
# Removed 1063 out of 5074 as noise (-1 label)
# Silhouette Coefficient: 0.0706
# Davies-Bouldin Index: 1.1725
# Calinski-Harabasz Index: 10.6424
# Adjusted Rand Index (ARI): 0.0001
# Number of clusters detected: 4
#
# Evaluating: eps=60, min_samples=7
# Removed 1099 out of 5074 as noise (-1 label)
# Silhouette Coefficient: 0.1687
# Davies-Bouldin Index: 1.0046
# Calinski-Harabasz Index: 16.8773
# Adjusted Rand Index (ARI): -0.0000
# Number of clusters detected: 2
#
# Evaluating: eps=60, min_samples=10
# Removed 1122 out of 5074 as noise (-1 label)
# Silhouette Coefficient: 0.1706
# Davies-Bouldin Index: 1.0017
# Calinski-Harabasz Index: 16.9919
# Adjusted Rand Index (ARI): 0.0000
# Number of clusters detected: 2
#
# Evaluating: eps=60, min_samples=15
# Removed 1161 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=70, min_samples=3
# Removed 250 out of 5074 as noise (-1 label)
# Silhouette Coefficient: 0.0165
# Davies-Bouldin Index: 1.1374
# Calinski-Harabasz Index: 5.0946
# Adjusted Rand Index (ARI): 0.0001
# Number of clusters detected: 6
#
# Evaluating: eps=70, min_samples=5
# Removed 267 out of 5074 as noise (-1 label)
# Silhouette Coefficient: 0.0538
# Davies-Bouldin Index: 1.2742
# Calinski-Harabasz Index: 6.9148
# Adjusted Rand Index (ARI): 0.0000
# Number of clusters detected: 3
#
# Evaluating: eps=70, min_samples=7
# Removed 283 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=70, min_samples=10
# Removed 289 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=70, min_samples=15
# Removed 305 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=80, min_samples=3
# Removed 49 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=80, min_samples=5
# Removed 49 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=80, min_samples=7
# Removed 49 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=80, min_samples=10
# Removed 49 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=80, min_samples=15
# Removed 50 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=90, min_samples=3
# Removed 7 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=90, min_samples=5
# Removed 7 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=90, min_samples=7
# Removed 7 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=90, min_samples=10
# Removed 7 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=90, min_samples=15
# Removed 7 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=100, min_samples=3
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=100, min_samples=5
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=100, min_samples=7
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=100, min_samples=10
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=100, min_samples=15
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=125, min_samples=3
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=125, min_samples=5
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=125, min_samples=7
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=125, min_samples=10
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=125, min_samples=15
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=150, min_samples=3
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=150, min_samples=5
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=150, min_samples=7
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=150, min_samples=10
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=150, min_samples=15
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=175, min_samples=3
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=175, min_samples=5
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=175, min_samples=7
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=175, min_samples=10
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
# Evaluating: eps=175, min_samples=15
# Removed 0 out of 5074 as noise (-1 label)
# Metrics cannot be computed (only 1 cluster found)
#
#
# Best Silhouette: 0.17055004535671284 with parameters: {'eps': 60, 'min_samples': 10}

# %%
df_results_B = pd.DataFrame(results_dbscan_respresentation_B)
df_results_B
# Out:
#     min_samples  eps  silhouette_avg  davies_bouldin  calinski_harabasz  ari
# 0             3   30            -1.0            -1.0               -1.0 -1.0
# 1             5   30            -1.0            -1.0               -1.0 -1.0
# 2             7   30            -1.0            -1.0               -1.0 -1.0
# 3            10   30            -1.0            -1.0               -1.0 -1.0
# 4            15   30            -1.0            -1.0               -1.0 -1.0
# ..          ...  ...             ...             ...                ...  ...
# 60            3  175            -1.0            -1.0               -1.0 -1.0
# 61            5  175            -1.0            -1.0               -1.0 -1.0
# 62            7  175            -1.0            -1.0               -1.0 -1.0
# 63           10  175            -1.0            -1.0               -1.0 -1.0
# 64           15  175            -1.0            -1.0               -1.0 -1.0
#
# [65 rows x 6 columns]

# %%
from sklearn.metrics import adjusted_rand_score, silhouette_score, davies_bouldin_score, calinski_harabasz_score

# Function to evaluate DBSCAN performance for a given combination of hyperparameters
def evaluate_kmeans(model, X, y):
    y_pred = model.labels_
    
    silhouette_avg = -1
    davies_bouldin = -1
    calinski_harabasz = -1
    ari = -1
    
    if len(np.unique(y_pred)) > 1:
        # Silhouette Coefficient (higher is better)
        silhouette_avg = silhouette_score(X, y_pred)
        print(f"Silhouette Coefficient: {silhouette_avg:.4f}")
        
        # Davies-Bouldin Index (lower is better)
        davies_bouldin = davies_bouldin_score(X, y_pred)
        print(f"Davies-Bouldin Index: {davies_bouldin:.4f}")
        
        # Calinski-Harabasz Index (higher is better)
        calinski_harabasz = calinski_harabasz_score(X, y_pred)
        print(f"Calinski-Harabasz Index: {calinski_harabasz:.4f}")
        
        # Optionally, print ARI for comparison with true labels
        ari = adjusted_rand_score(y, y_pred)
        print(f"Adjusted Rand Index (ARI): {ari:.4f}")
    else:
        print("Metrics cannot be computed (only 1 cluster found)")
    
    return silhouette_avg, davies_bouldin, calinski_harabasz, ari

# %% [markdown]
# # K-Means + Representation A

# %%
from sklearn.cluster import KMeans
from sklearn.model_selection import ParameterGrid

# Define parameter grid for KMeans
param_grid = {
    'n_clusters': range(2, 24, 1),  # testing different number of clusters
    'init': ['k-means++', 'random'],  # testing different initialization methods
    'max_iter': [25, 50, 100, 200, 300, 500, 1000],  # different maximum iterations
    'tol': [1e-4, 1e-3],  # different tolerance values
}

# Convert the grid into parameter combinations
grid = ParameterGrid(param_grid)

# Iterate over each parameter combination and evaluate
best_silhouette_avg = -1  # Track the best ARI score
best_params = None  # Track the best hyperparameters
results_kmeans_respresentation_A = {
    "n_clusters": [],
    "init": [],
    "max_iter": [],
    "tol": [],
    "silhouette_avg": [],
    "davies_bouldin": [],
    "calinski_harabasz": [],
    "ari": [],
    }

for params in grid:
    n_clusters = params['n_clusters']
    init = params['init']
    max_iter = params['max_iter']
    tol = params['tol']
    
    print(f"Evaluating: n_clusters={n_clusters}, init={init}, max_iter={max_iter}, tol={tol}")

    kmeans = KMeans(n_clusters=n_clusters, init=init, max_iter=max_iter, tol=tol)
    kmeans.fit_predict(X_train_flatten_pca)
    silhouette_avg, davies_bouldin, calinski_harabasz, ari = evaluate_kmeans(kmeans, X_train_flatten_pca, y_train_flatten)
    
    results_kmeans_respresentation_A['n_clusters'].append(n_clusters)
    results_kmeans_respresentation_A['init'].append(init)
    results_kmeans_respresentation_A['max_iter'].append(max_iter)
init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.1389
# Davies-Bouldin Index: 2.0290
# Calinski-Harabasz Index: 881.0229
# Adjusted Rand Index (ARI): 0.0636
#
# Evaluating: n_clusters=8, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.1304
# Davies-Bouldin Index: 1.9987
# Calinski-Harabasz Index: 806.6062
# Adjusted Rand Index (ARI): 0.0590
#
# Evaluating: n_clusters=8, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.1300
# Davies-Bouldin Index: 1.9997
# Calinski-Harabasz Index: 806.5446
# Adjusted Rand Index (ARI): 0.0622
#
# Evaluating: n_clusters=9, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.1255
# Davies-Bouldin Index: 2.0838
# Calinski-Harabasz Index: 739.1973
# Adjusted Rand Index (ARI): 0.0654
#
# Evaluating: n_clusters=9, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.1255
# Davies-Bouldin Index: 2.0686
# Calinski-Harabasz Index: 739.2824
# Adjusted Rand Index (ARI): 0.0655
#
# Evaluating: n_clusters=10, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.1198
# Davies-Bouldin Index: 2.1961
# Calinski-Harabasz Index: 682.0071
# Adjusted Rand Index (ARI): 0.0632
#
# Evaluating: n_clusters=10, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.1270
# Davies-Bouldin Index: 2.0920
# Calinski-Harabasz Index: 682.2832
# Adjusted Rand Index (ARI): 0.0648
#
# Evaluating: n_clusters=11, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.1114
# Davies-Bouldin Index: 2.1210
# Calinski-Harabasz Index: 637.0283
# Adjusted Rand Index (ARI): 0.0664
#
# Evaluating: n_clusters=11, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.1106
# Davies-Bouldin Index: 2.1571
# Calinski-Harabasz Index: 636.9968
# Adjusted Rand Index (ARI): 0.0665
#
# Evaluating: n_clusters=12, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.1122
# Davies-Bouldin Index: 2.1260
# Calinski-Harabasz Index: 598.6649
# Adjusted Rand Index (ARI): 0.0655
#
# Evaluating: n_clusters=12, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.1130
# Davies-Bouldin Index: 2.1230
# Calinski-Harabasz Index: 598.6013
# Adjusted Rand Index (ARI): 0.0656
#
# Evaluating: n_clusters=13, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.1141
# Davies-Bouldin Index: 2.1103
# Calinski-Harabasz Index: 564.2353
# Adjusted Rand Index (ARI): 0.0697
#
# Evaluating: n_clusters=13, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.1126
# Davies-Bouldin Index: 2.1131
# Calinski-Harabasz Index: 562.5895
# Adjusted Rand Index (ARI): 0.0658
#
# Evaluating: n_clusters=14, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.1129
# Davies-Bouldin Index: 2.0783
# Calinski-Harabasz Index: 535.1923
# Adjusted Rand Index (ARI): 0.0673
#
# Evaluating: n_clusters=14, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.1074
# Davies-Bouldin Index: 2.1218
# Calinski-Harabasz Index: 534.6803
# Adjusted Rand Index (ARI): 0.0595
#
# Evaluating: n_clusters=15, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.1130
# Davies-Bouldin Index: 2.1254
# Calinski-Harabasz Index: 508.4793
# Adjusted Rand Index (ARI): 0.0551
#
# Evaluating: n_clusters=15, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.1131
# Davies-Bouldin Index: 2.1756
# Calinski-Harabasz Index: 506.4714
# Adjusted Rand Index (ARI): 0.0612
#
# Evaluating: n_clusters=16, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.1061
# Davies-Bouldin Index: 2.0970
# Calinski-Harabasz Index: 484.7378
# Adjusted Rand Index (ARI): 0.0588
#
# Evaluating: n_clusters=16, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.1119
# Davies-Bouldin Index: 2.1730
# Calinski-Harabasz Index: 486.3424
# Adjusted Rand Index (ARI): 0.0567
#
# Evaluating: n_clusters=17, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.1096
# Davies-Bouldin Index: 2.0772
# Calinski-Harabasz Index: 466.2090
# Adjusted Rand Index (ARI): 0.0600
#
# Evaluating: n_clusters=17, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.1054
# Davies-Bouldin Index: 2.2176
# Calinski-Harabasz Index: 464.5745
# Adjusted Rand Index (ARI): 0.0589
#
# Evaluating: n_clusters=18, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.1097
# Davies-Bouldin Index: 2.0794
# Calinski-Harabasz Index: 447.2944
# Adjusted Rand Index (ARI): 0.0566
#
# Evaluating: n_clusters=18, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.1087
# Davies-Bouldin Index: 2.0900
# Calinski-Harabasz Index: 447.7271
# Adjusted Rand Index (ARI): 0.0587
#
# Evaluating: n_clusters=19, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.1113
# Davies-Bouldin Index: 2.1646
# Calinski-Harabasz Index: 430.0659
# Adjusted Rand Index (ARI): 0.0558
#
# Evaluating: n_clusters=19, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.1043
# Davies-Bouldin Index: 2.1477
# Calinski-Harabasz Index: 430.7469
# Adjusted Rand Index (ARI): 0.0567
#
# Evaluating: n_clusters=20, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.1047
# Davies-Bouldin Index: 2.1893
# Calinski-Harabasz Index: 413.0983
# Adjusted Rand Index (ARI): 0.0558
#
# Evaluating: n_clusters=20, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.1076
# Davies-Bouldin Index: 2.2110
# Calinski-Harabasz Index: 413.6341
# Adjusted Rand Index (ARI): 0.0579
#
# Evaluating: n_clusters=21, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.1102
# Davies-Bouldin Index: 2.1426
# Calinski-Harabasz Index: 401.6222
# Adjusted Rand Index (ARI): 0.0557
#
# Evaluating: n_clusters=21, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0975
# Davies-Bouldin Index: 2.2214
# Calinski-Harabasz Index: 398.5766
# Adjusted Rand Index (ARI): 0.0593
#
# Evaluating: n_clusters=22, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0967
# Davies-Bouldin Index: 2.1841
# Calinski-Harabasz Index: 387.0430
# Adjusted Rand Index (ARI): 0.0550
#
# Evaluating: n_clusters=22, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.1089
# Davies-Bouldin Index: 2.2530
# Calinski-Harabasz Index: 384.5329
# Adjusted Rand Index (ARI): 0.0573
#
# Evaluating: n_clusters=23, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0963
# Davies-Bouldin Index: 2.1809
# Calinski-Harabasz Index: 375.2673
# Adjusted Rand Index (ARI): 0.0538
#
# Evaluating: n_clusters=23, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0993
# Davies-Bouldin Index: 2.2164
# Calinski-Harabasz Index: 374.3239
# Adjusted Rand Index (ARI): 0.0504
#
# Evaluating: n_clusters=2, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.2623
# Davies-Bouldin Index: 1.4912
# Calinski-Harabasz Index: 2070.0075
# Adjusted Rand Index (ARI): 0.0128
#
# Evaluating: n_clusters=2, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.2623
# Davies-Bouldin Index: 1.4909
# Calinski-Harabasz Index: 2070.0054
# Adjusted Rand Index (ARI): 0.0128
#
# Evaluating: n_clusters=3, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.2079
# Davies-Bouldin Index: 1.7068
# Calinski-Harabasz Index: 1634.4199
# Adjusted Rand Index (ARI): 0.0249
#
# Evaluating: n_clusters=3, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.2082
# Davies-Bouldin Index: 1.7059
# Calinski-Harabasz Index: 1634.4014
# Adjusted Rand Index (ARI): 0.0246
#
# Evaluating: n_clusters=4, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1811
# Davies-Bouldin Index: 1.8535
# Calinski-Harabasz Index: 1284.0938
# Adjusted Rand Index (ARI): 0.0321
#
# Evaluating: n_clusters=4, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1808
# Davies-Bouldin Index: 1.8555
# Calinski-Harabasz Index: 1284.0771
# Adjusted Rand Index (ARI): 0.0317
#
# Evaluating: n_clusters=5, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1545
# Davies-Bouldin Index: 1.9419
# Calinski-Harabasz Index: 1119.9193
# Adjusted Rand Index (ARI): 0.0292
#
# Evaluating: n_clusters=5, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1544
# Davies-Bouldin Index: 1.9421
# Calinski-Harabasz Index: 1119.9148
# Adjusted Rand Index (ARI): 0.0292
#
# Evaluating: n_clusters=6, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1521
# Davies-Bouldin Index: 2.0071
# Calinski-Harabasz Index: 982.2597
# Adjusted Rand Index (ARI): 0.0509
#
# Evaluating: n_clusters=6, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1521
# Davies-Bouldin Index: 2.0081
# Calinski-Harabasz Index: 982.2225
# Adjusted Rand Index (ARI): 0.0508
#
# Evaluating: n_clusters=7, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1390
# Davies-Bouldin Index: 2.0248
# Calinski-Harabasz Index: 881.0661
# Adjusted Rand Index (ARI): 0.0633
#
# Evaluating: n_clusters=7, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1396
# Davies-Bouldin Index: 2.0134
# Calinski-Harabasz Index: 880.8894
# Adjusted Rand Index (ARI): 0.0624
#
# Evaluating: n_clusters=8, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1295
# Davies-Bouldin Index: 1.9861
# Calinski-Harabasz Index: 806.6814
# Adjusted Rand Index (ARI): 0.0617
#
# Evaluating: n_clusters=8, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1289
# Davies-Bouldin Index: 1.9892
# Calinski-Harabasz Index: 806.6491
# Adjusted Rand Index (ARI): 0.0616
#
# Evaluating: n_clusters=9, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1249
# Davies-Bouldin Index: 2.0696
# Calinski-Harabasz Index: 739.3464
# Adjusted Rand Index (ARI): 0.0653
#
# Evaluating: n_clusters=9, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1253
# Davies-Bouldin Index: 2.0944
# Calinski-Harabasz Index: 739.1856
# Adjusted Rand Index (ARI): 0.0648
#
# Evaluating: n_clusters=10, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1267
# Davies-Bouldin Index: 2.1096
# Calinski-Harabasz Index: 682.1847
# Adjusted Rand Index (ARI): 0.0653
#
# Evaluating: n_clusters=10, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1095
# Davies-Bouldin Index: 2.1066
# Calinski-Harabasz Index: 682.3417
# Adjusted Rand Index (ARI): 0.0689
#
# Evaluating: n_clusters=11, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1147
# Davies-Bouldin Index: 2.1065
# Calinski-Harabasz Index: 635.9611
# Adjusted Rand Index (ARI): 0.0701
#
# Evaluating: n_clusters=11, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1124
# Davies-Bouldin Index: 2.0923
# Calinski-Harabasz Index: 637.5290
# Adjusted Rand Index (ARI): 0.0668
#
# Evaluating: n_clusters=12, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1153
# Davies-Bouldin Index: 2.0885
# Calinski-Harabasz Index: 599.1082
# Adjusted Rand Index (ARI): 0.0650
#
# Evaluating: n_clusters=12, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1144
# Davies-Bouldin Index: 2.1126
# Calinski-Harabasz Index: 598.2400
# Adjusted Rand Index (ARI): 0.0675
#
# Evaluating: n_clusters=13, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1127
# Davies-Bouldin Index: 2.1273
# Calinski-Harabasz Index: 563.2464
# Adjusted Rand Index (ARI): 0.0671
#
# Evaluating: n_clusters=13, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1153
# Davies-Bouldin Index: 2.1016
# Calinski-Harabasz Index: 563.8029
# Adjusted Rand Index (ARI): 0.0698
#
# Evaluating: n_clusters=14, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1080
# Davies-Bouldin Index: 2.0772
# Calinski-Harabasz Index: 534.5961
# Adjusted Rand Index (ARI): 0.0602
#
# Evaluating: n_clusters=14, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1122
# Davies-Bouldin Index: 2.1840
# Calinski-Harabasz Index: 532.5699
# Adjusted Rand Index (ARI): 0.0628
#
# Evaluating: n_clusters=15, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1124
# Davies-Bouldin Index: 2.1881
# Calinski-Harabasz Index: 508.2217
# Adjusted Rand Index (ARI): 0.0590
#
# Evaluating: n_clusters=15, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1130
# Davies-Bouldin Index: 2.1038
# Calinski-Harabasz Index: 508.6950
# Adjusted Rand Index (ARI): 0.0691
#
# Evaluating: n_clusters=16, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1075
# Davies-Bouldin Index: 2.1352
# Calinski-Harabasz Index: 485.3136
# Adjusted Rand Index (ARI): 0.0585
#
# Evaluating: n_clusters=16, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1110
# Davies-Bouldin Index: 2.1115
# Calinski-Harabasz Index: 486.6287
# Adjusted Rand Index (ARI): 0.0594
#
# Evaluating: n_clusters=17, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1086
# Davies-Bouldin Index: 2.1605
# Calinski-Harabasz Index: 465.4256
# Adjusted Rand Index (ARI): 0.0571
#
# Evaluating: n_clusters=17, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1029
# Davies-Bouldin Index: 2.1474
# Calinski-Harabasz Index: 464.7366
# Adjusted Rand Index (ARI): 0.0599
#
# Evaluating: n_clusters=18, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1102
# Davies-Bouldin Index: 2.1879
# Calinski-Harabasz Index: 446.1430
# Adjusted Rand Index (ARI): 0.0590
#
# Evaluating: n_clusters=18, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1076
# Davies-Bouldin Index: 2.1537
# Calinski-Harabasz Index: 447.4349
# Adjusted Rand Index (ARI): 0.0586
#
# Evaluating: n_clusters=19, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1070
# Davies-Bouldin Index: 2.1067
# Calinski-Harabasz Index: 429.3150
# Adjusted Rand Index (ARI): 0.0580
#
# Evaluating: n_clusters=19, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1116
# Davies-Bouldin Index: 2.1506
# Calinski-Harabasz Index: 430.7580
# Adjusted Rand Index (ARI): 0.0572
#
# Evaluating: n_clusters=20, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1014
# Davies-Bouldin Index: 2.1709
# Calinski-Harabasz Index: 414.7682
# Adjusted Rand Index (ARI): 0.0546
#
# Evaluating: n_clusters=20, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1028
# Davies-Bouldin Index: 2.1758
# Calinski-Harabasz Index: 414.9545
# Adjusted Rand Index (ARI): 0.0594
#
# Evaluating: n_clusters=21, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1058
# Davies-Bouldin Index: 2.1781
# Calinski-Harabasz Index: 401.7859
# Adjusted Rand Index (ARI): 0.0568
#
# Evaluating: n_clusters=21, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1087
# Davies-Bouldin Index: 2.2444
# Calinski-Harabasz Index: 399.0098
# Adjusted Rand Index (ARI): 0.0592
#
# Evaluating: n_clusters=22, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0957
# Davies-Bouldin Index: 2.1804
# Calinski-Harabasz Index: 388.1104
# Adjusted Rand Index (ARI): 0.0589
#
# Evaluating: n_clusters=22, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0971
# Davies-Bouldin Index: 2.2112
# Calinski-Harabasz Index: 385.2940
# Adjusted Rand Index (ARI): 0.0588
#
# Evaluating: n_clusters=23, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0990
# Davies-Bouldin Index: 2.2186
# Calinski-Harabasz Index: 374.6106
# Adjusted Rand Index (ARI): 0.0543
#
# Evaluating: n_clusters=23, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1032
# Davies-Bouldin Index: 2.1737
# Calinski-Harabasz Index: 376.1652
# Adjusted Rand Index (ARI): 0.0568
#
#
# Best Silhouette: 0.262539184477526 with parameters: {'init': 'k-means++', 'max_iter': 25, 'n_clusters': 2, 'tol': 0.001}

# %%
df_kmeans_results_A = pd.DataFrame(results_kmeans_respresentation_A)
df_kmeans_results_A
# Out:
#      n_clusters       init  max_iter     tol  silhouette_avg  davies_bouldin  \
# 0             2  k-means++        25  0.0001        0.261888        1.493444
# 1             2  k-means++        25  0.0010        0.262539        1.489977
# 2             3  k-means++        25  0.0001        0.208240        1.706579
# 3             3  k-means++        25  0.0010        0.207600        1.705732
# 4             4  k-means++        25  0.0001        0.182760        1.846216
# ..          ...        ...       ...     ...             ...             ...
# 611          21     random      1000  0.0010        0.108744        2.244437
# 612          22     random      1000  0.0001        0.095698        2.180422
# 613          22     random      1000  0.0010        0.097057        2.211215
# 614          23     random      1000  0.0001        0.098960        2.218563
# 615          23     random      1000  0.0010        0.103191        2.173709
#
#      calinski_harabasz       ari
# 0          2069.977264  0.013146
# 1          2069.934675  0.012899
# 2          1634.418205  0.024788
# 3          1634.355689  0.024771
# 4          1284.110327  0.032065
# ..                 ...       ...
# 611         399.009818  0.059204
# 612         388.110424  0.058929
# 613         385.293972  0.058779
# 614         374.610602  0.054345
# 615         376.165163  0.056752
#
# [616 rows x 8 columns]

# %% [markdown]
# # K-Means + Representation B

# %%
from sklearn.cluster import KMeans
from sklearn.model_selection import ParameterGrid

# Define parameter grid for KMeans
param_grid = {
    'n_clusters': range(2, 24, 1),  # testing different number of clusters
    'init': ['k-means++', 'random'],  # testing different initialization methods
    'max_iter': [25, 50, 100, 200, 300, 500, 1000],  # different maximum iterations
    'tol': [1e-4, 1e-3],  # different tolerance values
}

# Convert the grid into parameter combinations
grid = ParameterGrid(param_grid)

# Iterate over each parameter combination and evaluate
best_silhouette_avg = -1  # Track the best ARI score
best_params = None  # Track the best hyperparameters
results_kmeans_respresentation_B = {
    "n_clusters": [],
    "init": [],
    "max_iter": [],
    "tol": [],
    "silhouette_avg": [],
    "davies_bouldin": [],
    "calinski_harabasz": [],
    "ari": [],
    }

for params in grid:
    n_clusters = params['n_clusters']
    init = params['init']
    max_iter = params['max_iter']
    tol = params['tol']
    
    print(f"Evaluating: n_clusters={n_clusters}, init={init}, max_iter={max_iter}, tol={tol}")

    kmeans = KMeans(n_clusters=n_clusters, init=init, max_iter=max_iter, tol=tol)
    kmeans.fit_predict(X_train_resnet)
    silhouette_avg, davies_bouldin, calinski_harabasz, ari = evaluate_kmeans(kmeans, X_train_resnet, y_train_resnet)
    
    results_kmeans_respresentation_B['n_clusters'].append(n_clusters)
    results_kmeans_respresentation_B['init'].append(init)
    results_kmeans_respresentation_B['max_iter'].append(max_iter)
    results_kmeans_respresentation_B['tol'].append(tol)
    results_kmeans_respresentation_B['silhouette_avg'].append(silhouette_avg)
    results_kmeans_respresentation_B['davies_bouldin'].append(davies_bouldin)
    results_kmeans_respresentation_B['calinski_harabasz'].append(calinski_harabasz)
    results_kmeans_respresentation_B['ari'].append(ari)
    print()
    
    if silhouette_avg > best_silhouette_avg:
        best_silhouette_avg = silhouette_avg
        best_params = params

print(f"\nBest Silhouette: {best_silhouette_avg} with parameters: {best_params}")
# Out:
# Evaluating: n_clusters=2, init=k-means++, max_iter=25, tol=0.0001
# Silhouette Coefficient: 0.1156
# Davies-Bouldin Index: 3.0747
# Calinski-Harabasz Index: 483.5906
# Adjusted Rand Index (ARI): 0.2160
#
# Evaluating: n_clusters=2, init=k-means++, max_iter=25, tol=0.001
# Silhouette Coefficient: 0.1156
# Davies-Bouldin Index: 3.0747
# Calinski-Harabasz Index: 483.5906
# Adjusted Rand Index (ARI): 0.2160
#
# Evaluating: n_clusters=3, init=k-means++, max_iter=25, tol=0.0001
# Silhouette Coefficient: 0.0832
# Davies-Bouldin Index: 3.4581
# Calinski-Harabasz Index: 362.5132
# Adjusted Rand Index (ARI): 0.2085
#
# Evaluating: n_clusters=3, init=k-means++, max_iter=25, tol=0.001
# Silhouette Coefficient: 0.1064
# Davies-Bouldin Index: 3.2455
# Calinski-Harabasz Index: 371.7638
# Adjusted Rand Index (ARI): 0.2366
#
# Evaluating: n_clusters=4, init=k-means++, max_iter=25, tol=0.0001
# Silhouette Coefficient: 0.0728
# Davies-Bouldin Index: 3.1525
# Calinski-Harabasz Index: 332.4024
# Adjusted Rand Index (ARI): 0.2723
#
# Evaluating: n_clusters=4, init=k-means++, max_iter=25, tol=0.001
# Silhouette Coefficient: 0.0951
# Davies-Bouldin Index: 2.9976
# Calinski-Harabasz Index: 335.3856
# Adjusted Rand Index (ARI): 0.2983
#
# Evaluating: n_clusters=5, init=k-means++, max_iter=25, tol=0.0001
# Silhouette Coefficient: 0.0794
# Davies-Bouldin Index: 2.8169
# Calinski-Harabasz Index: 321.8789
# Adjusted Rand Index (ARI): 0.3340
#
# Evaluating: n_clusters=5, init=k-means++, max_iter=25, tol=0.001
# Silhouette Coefficient: 0.0795
# Davies-Bouldin Index: 2.8165
# Calinski-Harabasz Index: 321.8765
# Adjusted Rand Index (ARI): 0.3348
#
# Evaluating: n_clusters=6, init=k-means++, max_iter=25, tol=0.0001
# Silhouette Coefficient: 0.0782
# Davies-Bouldin Index: 3.4916
# Calinski-Harabasz Index: 276.6378
# Adjusted Rand Index (ARI): 0.3259
#
# Evaluating: n_clusters=6, init=k-means++, max_iter=25, tol=0.001
# Silhouette Coefficient: 0.0780
# Davies-Bouldin Index: 3.5029
# Calinski-Harabasz Index: 276.5900
# Adjusted Rand Index (ARI): 0.3254
#
# Evaluating: n_clusters=7, init=k-means++, max_iter=25, tol=0.0001
# Silhouette Coefficient: 0.0465
# Davies-Bouldin Index: 3.6176
# Calinski-Harabasz Index: 244.9684
# Adjusted Rand Index (ARI): 0.3749
#
# Evaluating: n_clusters=7, init=k-means++, max_iter=25, tol=0.001
# Silhouette Coefficient: 0.0704
# Davies-Bouldin Index: 3.3994
# Calinski-Harabasz Index: 248.0962
# Adjusted Rand Index (ARI): 0.3523
#
# Evaluating: n_clusters=8, init=k-means++, max_iter=25, tol=0.0001
# Silhouette Coefficient: 0.0356
# Davies-Bouldin Index: 3.5687
# Calinski-Harabasz Index: 222.0505
# Adjusted Rand Index (ARI): 0.4002
#
# Evaluating: n_clusters=8, init=k-means++, max_iter=25, tol=0.001
# Silhouette Coefficient: 0.0471
# Davies-Bouldin Index: 3.0218
# Calinski-Harabasz Index: 229.5514
# Adjusted Rand Index (ARI): 0.4483
#
# Evaluating: n_clusters=9, init=k-means++, max_iter=25, tol=0.0001
# Silhouette Coefficient: 0.0474
# Davies-Bouldin Index: 3.3936
# Calinski-Harabasz Index: 211.4268
# Adjusted Rand Index (ARI): 0.4267
#
# Evaluating: n_clusters=9, init=k-means++, max_iter=25, tol=0.001
# Silhouette Coefficient: 0.0427
# Davies-Bouldin Index: 3.4850
# Calinski-Harabasz Index: 209.3543
# Adjusted Rand Index (ARI): 0.4082
#
# Evaluating: n_clusters=10, init=k-means++, max_iter=25, tol=0.0001
# Silhouette Coefficient: 0.0497
# Davies-Bouldin Index: 3.1336
# Calinski-Harabasz Index: 198.0856
# Adjusted Rand Index (ARI): 0.3805
#
# Evaluating: n_clusters=10, init=k-means++, max_iter=25, tol=0.001
# Silhouette Coefficient: 0.0529
# Davies-Bouldin Index: 3.2271
# Calinski-Harabasz Index: 199.7921
# Adjusted Rand Index (ARI): 0.4393
#
# Evaluating: n_clusters=11, init=k-means++, max_iter=25, tol=0.0001
# Silhouette Coefficient: 0.0492
# Davies-Bouldin Index: 3.2140
# Calinski-Harabasz Index: 186.0721
# Adjusted Rand Index (ARI): 0.3560
#
# Evaluating: n_clusters=11, init=k-means++, max_iter=25, tol=0.001
# Silhouette Coefficient: 0.
init=k-means++, max_iter=300, tol=0.001
# Silhouette Coefficient: 0.0489
# Davies-Bouldin Index: 3.2341
# Calinski-Harabasz Index: 151.3941
# Adjusted Rand Index (ARI): 0.3417
#
# Evaluating: n_clusters=16, init=k-means++, max_iter=300, tol=0.0001
# Silhouette Coefficient: 0.0515
# Davies-Bouldin Index: 3.2280
# Calinski-Harabasz Index: 146.8626
# Adjusted Rand Index (ARI): 0.3397
#
# Evaluating: n_clusters=16, init=k-means++, max_iter=300, tol=0.001
# Silhouette Coefficient: 0.0437
# Davies-Bouldin Index: 3.2121
# Calinski-Harabasz Index: 147.0352
# Adjusted Rand Index (ARI): 0.3524
#
# Evaluating: n_clusters=17, init=k-means++, max_iter=300, tol=0.0001
# Silhouette Coefficient: 0.0442
# Davies-Bouldin Index: 3.3696
# Calinski-Harabasz Index: 139.6671
# Adjusted Rand Index (ARI): 0.3131
#
# Evaluating: n_clusters=17, init=k-means++, max_iter=300, tol=0.001
# Silhouette Coefficient: 0.0500
# Davies-Bouldin Index: 3.1998
# Calinski-Harabasz Index: 140.9126
# Adjusted Rand Index (ARI): 0.3129
#
# Evaluating: n_clusters=18, init=k-means++, max_iter=300, tol=0.0001
# Silhouette Coefficient: 0.0506
# Davies-Bouldin Index: 3.2562
# Calinski-Harabasz Index: 135.0563
# Adjusted Rand Index (ARI): 0.3000
#
# Evaluating: n_clusters=18, init=k-means++, max_iter=300, tol=0.001
# Silhouette Coefficient: 0.0474
# Davies-Bouldin Index: 3.2783
# Calinski-Harabasz Index: 134.9418
# Adjusted Rand Index (ARI): 0.3031
#
# Evaluating: n_clusters=19, init=k-means++, max_iter=300, tol=0.0001
# Silhouette Coefficient: 0.0478
# Davies-Bouldin Index: 3.3337
# Calinski-Harabasz Index: 129.8000
# Adjusted Rand Index (ARI): 0.2897
#
# Evaluating: n_clusters=19, init=k-means++, max_iter=300, tol=0.001
# Silhouette Coefficient: 0.0520
# Davies-Bouldin Index: 3.3238
# Calinski-Harabasz Index: 126.7765
# Adjusted Rand Index (ARI): 0.3285
#
# Evaluating: n_clusters=20, init=k-means++, max_iter=300, tol=0.0001
# Silhouette Coefficient: 0.0497
# Davies-Bouldin Index: 3.3413
# Calinski-Harabasz Index: 125.5595
# Adjusted Rand Index (ARI): 0.2814
#
# Evaluating: n_clusters=20, init=k-means++, max_iter=300, tol=0.001
# Silhouette Coefficient: 0.0416
# Davies-Bouldin Index: 3.3403
# Calinski-Harabasz Index: 125.0752
# Adjusted Rand Index (ARI): 0.3015
#
# Evaluating: n_clusters=21, init=k-means++, max_iter=300, tol=0.0001
# Silhouette Coefficient: 0.0478
# Davies-Bouldin Index: 3.3729
# Calinski-Harabasz Index: 119.2096
# Adjusted Rand Index (ARI): 0.2848
#
# Evaluating: n_clusters=21, init=k-means++, max_iter=300, tol=0.001
# Silhouette Coefficient: 0.0484
# Davies-Bouldin Index: 3.3099
# Calinski-Harabasz Index: 117.2635
# Adjusted Rand Index (ARI): 0.2947
#
# Evaluating: n_clusters=22, init=k-means++, max_iter=300, tol=0.0001
# Silhouette Coefficient: 0.0500
# Davies-Bouldin Index: 3.3090
# Calinski-Harabasz Index: 116.9478
# Adjusted Rand Index (ARI): 0.2663
#
# Evaluating: n_clusters=22, init=k-means++, max_iter=300, tol=0.001
# Silhouette Coefficient: 0.0482
# Davies-Bouldin Index: 3.3249
# Calinski-Harabasz Index: 116.7028
# Adjusted Rand Index (ARI): 0.3156
#
# Evaluating: n_clusters=23, init=k-means++, max_iter=300, tol=0.0001
# Silhouette Coefficient: 0.0510
# Davies-Bouldin Index: 3.2546
# Calinski-Harabasz Index: 113.5600
# Adjusted Rand Index (ARI): 0.2630
#
# Evaluating: n_clusters=23, init=k-means++, max_iter=300, tol=0.001
# Silhouette Coefficient: 0.0398
# Davies-Bouldin Index: 3.2435
# Calinski-Harabasz Index: 112.4866
# Adjusted Rand Index (ARI): 0.2797
#
# Evaluating: n_clusters=2, init=k-means++, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.1156
# Davies-Bouldin Index: 3.0747
# Calinski-Harabasz Index: 483.5906
# Adjusted Rand Index (ARI): 0.2160
#
# Evaluating: n_clusters=2, init=k-means++, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.1159
# Davies-Bouldin Index: 3.0726
# Calinski-Harabasz Index: 483.5920
# Adjusted Rand Index (ARI): 0.2154
#
# Evaluating: n_clusters=3, init=k-means++, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.1071
# Davies-Bouldin Index: 3.2273
# Calinski-Harabasz Index: 371.7578
# Adjusted Rand Index (ARI): 0.2379
#
# Evaluating: n_clusters=3, init=k-means++, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.
max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0406
# Davies-Bouldin Index: 3.4367
# Calinski-Harabasz Index: 161.2879
# Adjusted Rand Index (ARI): 0.3735
#
# Evaluating: n_clusters=14, init=k-means++, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0469
# Davies-Bouldin Index: 3.3102
# Calinski-Harabasz Index: 160.5652
# Adjusted Rand Index (ARI): 0.3426
#
# ...
# Silhouette Coefficient: 0.0795
# Davies-Bouldin Index: 2.8167
# Calinski-Harabasz Index: 321.8805
# Adjusted Rand Index (ARI): 0.3343
#
# Evaluating: n_clusters=5, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0795
# Davies-Bouldin Index: 2.8164
# Calinski-Harabasz Index: 321.8780
# Adjusted Rand Index (ARI): 0.3339
#
# Evaluating: n_clusters=6, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0531
# Davies-Bouldin Index: 3.0170
# Calinski-Harabasz Index: 282.1273
# Adjusted Rand Index (ARI): 0.4426
#
# Evaluating: n_clusters=6, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0477
# Davies-Bouldin Index: 3.0179
# Calinski-Harabasz Index: 282.7805
# Adjusted Rand Index (ARI): 0.4438
#
# Evaluating: n_clusters=7, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0576
# Davies-Bouldin Index: 3.0105
# Calinski-Harabasz Index: 252.8889
# Adjusted Rand Index (ARI): 0.4003
#
# Evaluating: n_clusters=7, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0550
# Davies-Bouldin Index: 3.0178
# Calinski-Harabasz Index: 252.4481
# Adjusted Rand Index (ARI): 0.4662
#
# Evaluating: n_clusters=8, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0494
# Davies-Bouldin Index: 3.3005
# Calinski-Harabasz Index: 230.7193
# Adjusted Rand Index (ARI): 0.3863
#
# Evaluating: n_clusters=8, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0477
# Davies-Bouldin Index: 3.3549
# Calinski-Harabasz Index: 230.7101
# Adjusted Rand Index (ARI): 0.4461
#
# Evaluating: n_clusters=9, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0518
# Davies-Bouldin Index: 3.2491
# Calinski-Harabasz Index: 215.4082
# Adjusted Rand Index (ARI): 0.4089
#
# Evaluating: n_clusters=9, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0514
# Davies-Bouldin Index: 3.2233
# Calinski-Harabasz Index: 215.3773
# Adjusted Rand Index (ARI): 0.4009
#
# Evaluating: n_clusters=10, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0527
# Davies-Bouldin Index: 3.2296
# Calinski-Harabasz Index: 202.2065
# Adjusted Rand Index (ARI): 0.4198
#
# Evaluating: n_clusters=10, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0540
# Davies-Bouldin Index: 3.1945
# Calinski-Harabasz Index: 202.3516
# Adjusted Rand Index (ARI): 0.4374
#
# Evaluating: n_clusters=11, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0563
# Davies-Bouldin Index: 3.1579
# Calinski-Harabasz Index: 190.0422
# Adjusted Rand Index (ARI): 0.4302
#
# Evaluating: n_clusters=11, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0565
# Davies-Bouldin Index: 3.1642
# Calinski-Harabasz Index: 190.1879
# Adjusted Rand Index (ARI): 0.4314
#
# Evaluating: n_clusters=12, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0504
# Davies-Bouldin Index: 3.2811
# Calinski-Harabasz Index: 178.6727
# Adjusted Rand Index (ARI): 0.4049
#
# Evaluating: n_clusters=12, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0556
# Davies-Bouldin Index: 3.1162
# Calinski-Harabasz Index: 179.3317
# Adjusted Rand Index (ARI): 0.3938
#
# Evaluating: n_clusters=13, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0501
# Davies-Bouldin Index: 3.2412
# Calinski-Harabasz Index: 169.8994
# Adjusted Rand Index (ARI): 0.3712
#
# Evaluating: n_clusters=13, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0576
# Davies-Bouldin Index: 3.0537
# Calinski-Harabasz Index: 169.4881
# Adjusted Rand Index (ARI): 0.3721
#
# Evaluating: n_clusters=14, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0525
# Davies-Bouldin Index: 3.1171
# Calinski-Harabasz Index: 161.3055
# Adjusted Rand Index (ARI): 0.3658
#
# Evaluating: n_clusters=14, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0554
# Davies-Bouldin Index: 3.1502
# Calinski-Harabasz Index: 162.0031
# Adjusted Rand Index (ARI): 0.3719
#
# Evaluating: n_clusters=15, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0507
# Davies-Bouldin Index: 3.1844
# Calinski-Harabasz Index: 154.2855
# Adjusted Rand Index (ARI): 0.3491
#
# Evaluating: n_clusters=15, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0515
# Davies-Bouldin Index: 3.1906
# Calinski-Harabasz Index: 154.2610
# Adjusted Rand Index (ARI): 0.3495
#
# Evaluating: n_clusters=16, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0499
# Davies-Bouldin Index: 3.2258
# Calinski-Harabasz Index: 147.4509
# Adjusted Rand Index (ARI): 0.3187
#
# Evaluating: n_clusters=16, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0526
# Davies-Bouldin Index: 3.1948
# Calinski-Harabasz Index: 147.4760
# Adjusted Rand Index (ARI): 0.3380
#
# Evaluating: n_clusters=17, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0508
# Davies-Bouldin Index: 3.2791
# Calinski-Harabasz Index: 141.3443
# Adjusted Rand Index (ARI): 0.3074
#
# Evaluating: n_clusters=17, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0524
# Davies-Bouldin Index: 3.2466
# Calinski-Harabasz Index: 140.8371
# Adjusted Rand Index (ARI): 0.3234
#
# Evaluating: n_clusters=18, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0486
# Davies-Bouldin Index: 3.2583
# Calinski-Harabasz Index: 135.8769
# Adjusted Rand Index (ARI): 0.2938
#
# Evaluating: n_clusters=18, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0479
# Davies-Bouldin Index: 3.2697
# Calinski-Harabasz Index: 135.7913
# Adjusted Rand Index (ARI): 0.3029
#
# Evaluating: n_clusters=19, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0497
# Davies-Bouldin Index: 3.2506
# Calinski-Harabasz Index: 130.7701
# Adjusted Rand Index (ARI): 0.2868
#
# Evaluating: n_clusters=19, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0561
# Davies-Bouldin Index: 3.2168
# Calinski-Harabasz Index: 130.2701
# Adjusted Rand Index (ARI): 0.3210
#
# Evaluating: n_clusters=20, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0522
# Davies-Bouldin Index: 3.2297
# Calinski-Harabasz Index: 126.6489
# Adjusted Rand Index (ARI): 0.2821
#
# Evaluating: n_clusters=20, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0469
# Davies-Bouldin Index: 3.2558
# Calinski-Harabasz Index: 127.0994
# Adjusted Rand Index (ARI): 0.2976
#
# Evaluating: n_clusters=21, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0475
# Davies-Bouldin Index: 3.2437
# Calinski-Harabasz Index: 122.9992
# Adjusted Rand Index (ARI): 0.2948
#
# Evaluating: n_clusters=21, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0459
# Davies-Bouldin Index: 3.3081
# Calinski-Harabasz Index: 121.9930
# Adjusted Rand Index (ARI): 0.2929
#
# Evaluating: n_clusters=22, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0454
# Davies-Bouldin Index: 3.2837
# Calinski-Harabasz Index: 117.7602
# Adjusted Rand Index (ARI): 0.2890
#
# Evaluating: n_clusters=22, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0442
# Davies-Bouldin Index: 3.3594
# Calinski-Harabasz Index: 117.2893
# Adjusted Rand Index (ARI): 0.2837
#
# Evaluating: n_clusters=23, init=random, max_iter=500, tol=0.0001
# Silhouette Coefficient: 0.0460
# Davies-Bouldin Index: 3.2531
# Calinski-Harabasz Index: 114.1734
# Adjusted Rand Index (ARI): 0.2827
#
# Evaluating: n_clusters=23, init=random, max_iter=500, tol=0.001
# Silhouette Coefficient: 0.0458
# Davies-Bouldin Index: 3.3277
# Calinski-Harabasz Index: 114.8929
# Adjusted Rand Index (ARI): 0.2807
#
# Evaluating: n_clusters=2, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1159
# Davies-Bouldin Index: 3.0726
# Calinski-Harabasz Index: 483.5920
# Adjusted Rand Index (ARI): 0.2154
#
# Evaluating: n_clusters=2, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.1159
# Davies-Bouldin Index: 3.0726
# Calinski-Harabasz Index: 483.5920
# Adjusted Rand Index (ARI): 0.2154
#
# Evaluating: n_clusters=3, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.1066
# Davies-Bouldin Index: 3.2408
# Calinski-Harabasz Index: 371.7786
# Adjusted Rand Index (ARI): 0.2371
#
# Evaluating: n_clusters=3, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0651
# Davies-Bouldin Index: 3.1320
# Calinski-Harabasz Index: 370.4507
# Adjusted Rand Index (ARI): 0.2767
#
# Evaluating: n_clusters=4, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0787
# Davies-Bouldin Index: 3.0407
# Calinski-Harabasz Index: 341.7373
# Adjusted Rand Index (ARI): 0.2987
#
# Evaluating: n_clusters=4, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0787
# Davies-Bouldin Index: 3.0398
# Calinski-Harabasz Index: 341.7371
# Adjusted Rand Index (ARI): 0.2986
#
# Evaluating: n_clusters=5, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0795
# Davies-Bouldin Index: 2.8164
# Calinski-Harabasz Index: 321.8799
# Adjusted Rand Index (ARI): 0.3331
#
# Evaluating: n_clusters=5, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0795
# Davies-Bouldin Index: 2.8167
# Calinski-Harabasz Index: 321.8786
# Adjusted Rand Index (ARI): 0.3335
#
# Evaluating: n_clusters=6, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0475
# Davies-Bouldin Index: 3.0165
# Calinski-Harabasz Index: 282.7854
# Adjusted Rand Index (ARI): 0.4425
#
# Evaluating: n_clusters=6, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0442
# Davies-Bouldin Index: 3.0123
# Calinski-Harabasz Index: 282.7725
# Adjusted Rand Index (ARI): 0.4404
#
# Evaluating: n_clusters=7, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0516
# Davies-Bouldin Index: 3.0060
# Calinski-Harabasz Index: 253.5292
# Adjusted Rand Index (ARI): 0.3958
#
# Evaluating: n_clusters=7, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0576
# Davies-Bouldin Index: 3.0115
# Calinski-Harabasz Index: 252.8877
# Adjusted Rand Index (ARI): 0.4005
#
# Evaluating: n_clusters=8, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0503
# Davies-Bouldin Index: 3.2905
# Calinski-Harabasz Index: 230.7603
# Adjusted Rand Index (ARI): 0.3774
#
# Evaluating: n_clusters=8, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0595
# Davies-Bouldin Index: 3.0070
# Calinski-Harabasz Index: 232.0539
# Adjusted Rand Index (ARI): 0.4243
#
# Evaluating: n_clusters=9, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0522
# Davies-Bouldin Index: 3.0003
# Calinski-Harabasz Index: 214.8071
# Adjusted Rand Index (ARI): 0.4014
#
# Evaluating: n_clusters=9, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0507
# Davies-Bouldin Index: 3.2564
# Calinski-Harabasz Index: 213.5564
# Adjusted Rand Index (ARI): 0.4173
#
# Evaluating: n_clusters=10, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0528
# Davies-Bouldin Index: 3.1904
# Calinski-Harabasz Index: 200.2297
# Adjusted Rand Index (ARI): 0.4402
#
# Evaluating: n_clusters=10, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0541
# Davies-Bouldin Index: 3.2095
# Calinski-Harabasz Index: 200.3837
# Adjusted Rand Index (ARI): 0.3894
#
# Evaluating: n_clusters=11, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0532
# Davies-Bouldin Index: 3.2080
# Calinski-Harabasz Index: 190.1702
# Adjusted Rand Index (ARI): 0.4251
#
# Evaluating: n_clusters=11, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0566
# Davies-Bouldin Index: 3.1588
# Calinski-Harabasz Index: 190.1998
# Adjusted Rand Index (ARI): 0.4320
#
# Evaluating: n_clusters=12, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0553
# Davies-Bouldin Index: 3.2210
# Calinski-Harabasz Index: 179.0484
# Adjusted Rand Index (ARI): 0.4142
#
# Evaluating: n_clusters=12, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0555
# Davies-Bouldin Index: 3.1060
# Calinski-Harabasz Index: 179.3745
# Adjusted Rand Index (ARI): 0.3831
#
# Evaluating: n_clusters=13, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0552
# Davies-Bouldin Index: 3.1555
# Calinski-Harabasz Index: 169.4421
# Adjusted Rand Index (ARI): 0.3777
#
# Evaluating: n_clusters=13, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0515
# Davies-Bouldin Index: 3.1757
# Calinski-Harabasz Index: 169.3107
# Adjusted Rand Index (ARI): 0.3811
#
# Evaluating: n_clusters=14, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0560
# Davies-Bouldin Index: 3.1576
# Calinski-Harabasz Index: 161.3440
# Adjusted Rand Index (ARI): 0.3809
#
# Evaluating: n_clusters=14, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0528
# Davies-Bouldin Index: 3.2375
# Calinski-Harabasz Index: 161.2984
# Adjusted Rand Index (ARI): 0.3587
#
# Evaluating: n_clusters=15, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0508
# Davies-Bouldin Index: 3.1839
# Calinski-Harabasz Index: 154.2332
# Adjusted Rand Index (ARI): 0.3479
#
# Evaluating: n_clusters=15, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0552
# Davies-Bouldin Index: 3.1200
# Calinski-Harabasz Index: 154.8316
# Adjusted Rand Index (ARI): 0.3577
#
# Evaluating: n_clusters=16, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0481
# Davies-Bouldin Index: 3.1414
# Calinski-Harabasz Index: 146.9903
# Adjusted Rand Index (ARI): 0.3506
#
# Evaluating: n_clusters=16, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0507
# Davies-Bouldin Index: 3.2157
# Calinski-Harabasz Index: 147.6596
# Adjusted Rand Index (ARI): 0.3167
#
# Evaluating: n_clusters=17, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0486
# Davies-Bouldin Index: 3.1834
# Calinski-Harabasz Index: 141.2227
# Adjusted Rand Index (ARI): 0.2989
#
# Evaluating: n_clusters=17, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0462
# Davies-Bouldin Index: 3.1328
# Calinski-Harabasz Index: 141.6843
# Adjusted Rand Index (ARI): 0.3471
#
# Evaluating: n_clusters=18, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0485
# Davies-Bouldin Index: 3.2673
# Calinski-Harabasz Index: 135.8249
# Adjusted Rand Index (ARI): 0.2949
#
# Evaluating: n_clusters=18, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0489
# Davies-Bouldin Index: 3.2083
# Calinski-Harabasz Index: 136.0081
# Adjusted Rand Index (ARI): 0.3336
#
# Evaluating: n_clusters=19, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0476
# Davies-Bouldin Index: 3.2069
# Calinski-Harabasz Index: 131.5701
# Adjusted Rand Index (ARI): 0.3280
#
# Evaluating: n_clusters=19, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0506
# Davies-Bouldin Index: 3.2531
# Calinski-Harabasz Index: 130.6625
# Adjusted Rand Index (ARI): 0.3359
#
# Evaluating: n_clusters=20, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0495
# Davies-Bouldin Index: 3.1834
# Calinski-Harabasz Index: 127.1497
# Adjusted Rand Index (ARI): 0.3198
#
# Evaluating: n_clusters=20, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0465
# Davies-Bouldin Index: 3.2616
# Calinski-Harabasz Index: 127.0469
# Adjusted Rand Index (ARI): 0.3041
#
# Evaluating: n_clusters=21, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0460
# Davies-Bouldin Index: 3.2395
# Calinski-Harabasz Index: 122.0431
# Adjusted Rand Index (ARI): 0.2955
#
# Evaluating: n_clusters=21, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0482
# Davies-Bouldin Index: 3.2462
# Calinski-Harabasz Index: 121.4244
# Adjusted Rand Index (ARI): 0.3167
#
# Evaluating: n_clusters=22, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0490
# Davies-Bouldin Index: 3.1970
# Calinski-Harabasz Index: 118.6445
# Adjusted Rand Index (ARI): 0.2949
#
# Evaluating: n_clusters=22, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0407
# Davies-Bouldin Index: 3.3167
# Calinski-Harabasz Index: 117.6511
# Adjusted Rand Index (ARI): 0.2788
#
# Evaluating: n_clusters=23, init=random, max_iter=1000, tol=0.0001
# Silhouette Coefficient: 0.0445
# Davies-Bouldin Index: 3.3484
# Calinski-Harabasz Index: 113.3531
# Adjusted Rand Index (ARI): 0.2779
#
# Evaluating: n_clusters=23, init=random, max_iter=1000, tol=0.001
# Silhouette Coefficient: 0.0465
# Davies-Bouldin Index: 3.3134
# Calinski-Harabasz Index: 114.1740
# Adjusted Rand Index (ARI): 0.2790
#
#
# Best Silhouette: 0.11594240367412567 with parameters: {'init': 'k-means++', 'max_iter': 50, 'n_clusters': 2, 'tol': 0.001}

# %%
df_kmeans_results_B = pd.DataFrame(results_kmeans_respresentation_B)
df_kmeans_results_B
# Out:
#      n_clusters       init  max_iter     tol  silhouette_avg  davies_bouldin  \
# 0             2  k-means++        25  0.0001        0.115645        3.074748
# 1             2  k-means++        25  0.0010        0.115645        3.074748
# 2             3  k-means++        25  0.0001        0.083205        3.458083
# 3             3  k-means++        25  0.0010        0.106354        3.245460
# 4             4  k-means++        25  0.0001        0.072788        3.152497
# ..          ...        ...       ...     ...             ...             ...
# 611          21     random      1000  0.0010        0.048210        3.246216
# 612          22     random      1000  0.0001        0.049012        3.197041
# 613          22     random      1000  0.0010        0.040671        3.316715
# 614          23     random      1000  0.0001        0.044530        3.348399
# 615          23     random      1000  0.0010        0.046523        3.313378
#
#      calinski_harabasz       ari
# 0           483.590603  0.216006
# 1           483.590603  0.216006
# 2           362.513168  0.208474
# 3           371.763807  0.236597
# 4           332.402354  0.272277
# ..                 ...       ...
# 611         121.424392  0.316741
# 612         118.644462  0.294944
# 613         117.651077  0.278785
# 614         113.353082  0.277901
# 615         114.174033  0.279047
#
# [616 rows x 8 columns]
